# %% [markdown]
# ## Python basic data structures

# %% [markdown]
# #### A data structure is a way to store and organize data in a computer so that we can access and modify it efficiently.
#
# * In Python, data structures are built-in types that help us handle data easily.
#
# **Common 4 Python Data Structures:**
#
# * List
#
# * Tuple
#
# * Set
#
# * Dictionary

# %% [markdown]
# ### 1. List
#
# **A list is an ordered collection of items in Python.**
#
# * It is mutable → you can change, add, or remove items.
#
# * It allows duplicates.
#
# * Defined using square brackets []
#
# * Lists are heterogeneous, meaning they can store multiple data types in a single list.

# %%
empty_cart = []

# %%
empty_cart
# Out:
# []

# %%
type(empty_cart)
# Out:
# list

# %%
shopping_list = ["Rice", "Milk", "Eggs", "Bread", "Sugar", "Tea" , "Rice" , 9.99 , 69]
shopping_list
# Out:
# ['Rice', 'Milk', 'Eggs', 'Bread', 'Sugar', 'Tea', 'Rice', 9.99, 69]

# %%
type(shopping_list)
# Out:
# list

# %%
len(shopping_list)
# Out:
# 9

# %%
shopping_list[0]
# Out:
# 'Rice'

# %%
shopping_list[0:3]
# Out:
# ['Rice', 'Milk', 'Eggs']

# %%
shopping_list[:3]
# Out:
# ['Rice', 'Milk', 'Eggs']

# %%
shopping_list[2] = "fruits"

# %%
shopping_list
# Out:
# ['Rice', 'Milk', 'fruits', 'Bread', 'Sugar', 'Tea', 'Rice', 9.99, 69]

# %% [markdown]
# ### 2. Set
#
# **Definition:**
# * A set is an unordered collection of items in Python.
#
# * It is mutable (you can add or remove items)
#
# * It does NOT allow duplicate values
#
# * Defined using curly braces {}

# %%
empty_cart02 = set()

# %%
empty_cart02
# Out:
# set()

# %%
type(empty_cart02 )
# Out:
# set

# %%
shopping_list02 = {"Rice", "Milk", "Eggs", "Bread", "Sugar", "Tea" , "Rice" , 9.99 , 69}
shopping_list02
# Out:
# {69, 9.99, 'Bread', 'Eggs', 'Milk', 'Rice', 'Sugar', 'Tea'}

# %%
type(shopping_list02)
# Out:
# set

# %%
shopping_list02 [0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 shopping_list02 [0]
#
# TypeError: 'set' object is not subscriptable

# %%
shopping_list02 [2] = "fruits"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 shopping_list02 [2] = "fruits"
#
# TypeError: 'set' object does not support item assignment

# %%
shopping_list02.add("fruits")

# %%
shopping_list02
# Out:
# {69,
#  9.99,
#  'Bread',
#  'Milk',
#  'Rice',
#  'Sugar',
#  'Tea',
#  'beffe',
#  'fruits',
#  'g',
#  's'}

# %%
shopping_list02.remove("fruits")
shopping_list02
# Out:
# {69, 9.99, 'Bread', 'Milk', 'Rice', 'Sugar', 'Tea', 'beffe', 'g', 's'}

# %% [markdown]
# ### Tuple
#
# **Definition:**
# * A tuple is an ordered collection of items in Python.
#
# * It is immutable → values cannot be changed after creation
#
# * It allows duplicate values
#
# * Defined using parentheses ()

# %%
empty_cart03 = ()
empty_cart03
# Out:
# ()

# %%
type(empty_cart03)
# Out:
# tuple

# %%
shopping_list03 = ("Rice", "Milk", "Eggs", "Bread", "Sugar", "Tea" , "Rice" , 9.99 , 69)
shopping_list03
# Out:
# ('Rice', 'Milk', 'Eggs', 'Bread', 'Sugar', 'Tea', 'Rice', 9.99, 69)

# %%
shopping_list03 [0]
# Out:
# 'Rice'

# %%
shopping_list03[0:3]
# Out:
# ('Rice', 'Milk', 'Eggs')

# %%
shopping_list03 [2] = "fruits"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 shopping_list03 [2] = "fruits"
#
# TypeError: 'tuple' object does not support item assignment

# %%
shopping_list03.count("Bread")
# Out:
# 1

# %% [markdown]
# ### Dictionary
#
# **Definition:**
# * A dictionary is a collection of key–value pairs in Python.
#
# * It is mutable
#
# * Keys must be unique
#
# * Values can be duplicated
#
# * Defined using curly braces {} with :

# %%
empty_cart04 = {}

# %%
empty_cart04
# Out:
# {}

# %%
type(empty_cart04)
# Out:
# dict

# %%
shopping_list04 = {"Rice" : 2,
                   "Milk" : 1,
                   "Eggs" : 10,
                   "Bread" : 3, 
                   "Sugar" : 1, 
                   "Tea" : 1 , }

# %%
shopping_list04
# Out:
# {'Rice': 2, 'Milk': 1, 'Eggs': 10, 'Bread': 3, 'Sugar': 1, 'Tea': 1}

# %%
shopping_list04.clear()

# %%
shopping_list04
# Out:
# {}

# %%
shopping_list04.keys()
# Out:
# dict_keys(['Rice', 'Milk', 'Eggs', 'Bread', 'Sugar', 'Tea'])

# %%
shopping_list04.values()
# Out:
# dict_values([2, 1, 10, 3, 1, 1])

# %%
shopping_list04 = {"Rice" : 2,
                   "Milk" : 1,
                   "Eggs" : 10,
                   "Bread" : 3, 
                   "Sugar" : 1, 
                   "Tea" : 1 , }
shopping_list04
# Out:
# {'Rice': 2, 'Milk': 1, 'Eggs': 10, 'Bread': 3, 'Sugar': 1, 'Tea': 1}

# %%
import pandas as pd

# %%
shopping_list_new = {"items" : ["Rice", "Milk", "Eggs", "Bread", "Sugar", "Tea"] , "Count" : [2,1,10,3,1,1]}
shopping_list_new
# Out:
# {'items': ['Rice', 'Milk', 'Eggs', 'Bread', 'Sugar', 'Tea'],
#  'Count': [2, 1, 10, 3, 1, 1]}

# %%
pd.DataFrame(data=shopping_list_new)
# Out:
#    items  Count
# 0   Rice      2
# 1   Milk      1
# 2   Eggs     10
# 3  Bread      3
# 4  Sugar      1
# 5    Tea      1
