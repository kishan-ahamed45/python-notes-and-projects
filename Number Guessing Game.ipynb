# %% [markdown]
# ## Number Guessing Game Level 1

# %% [markdown]
# ### 1.Print if the user guessed number is right or not

# %%
num = 56

user_num = int(input("Enter you'r guessing number : "))

if num == user_num:
     print("congratulations You'r guess is right")
else:
    print("Sorry You'r guess is wrong")

# %% [markdown]
# ### ------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ###

# %% [markdown]
# ## Number Guessing Game Level 2

# %% [markdown]
# ### 2.Print if the user guessed number is rigth or wrong with max of 7 trials

# %% [markdown]
# #### 2.1 Using for loop - End intertion is defined

# %%
num = 67

for i in range(0,7):
    user_num = int(input("Enter you'r guessing numbera : "))

    if num == user_num:
        print("congratulations You'r guess is right")
        break
    else:
        print("Sorry You'r guess is wrong")
# Out:
# Enter you'r guessing numbera :  45
# Sorry You'r guess is wrong
# Enter you'r guessing numbera :  87
# Sorry You'r guess is wrong
# Enter you'r guessing numbera :  41
# Sorry You'r guess is wrong
# Enter you'r guessing numbera :  67
# congratulations You'r guess is right

# %% [markdown]
# #### 2.2 While Loop - When end Number is not defined and the intertions has to executed infinite times

# %%
num = 67

while True:
    user_num = int(input("Enter you'r guessing number : "))

    if num == user_num:
        print("congratulations You'r guess is right")
        break
    else:
        print("Sorry You'r guess is wrong")
# Out:
# Enter you'r guessing number :  md
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 4
#       1 num = 67
#       3 while True:
# ----> 4     user_num = int(input("Enter you'r guessing number : "))
#       6     if num == user_num:
#       7         print("congratulations You'r guess is right")
#
# ValueError: invalid literal for int() with base 10: 'md'

# %% [markdown]
# ### ------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Number Guessing Game Level 3

# %% [markdown]
# #### Give Multiple Number's
#
# 1.User should enter the number 1 - 100
#
# 2.if the gusseed number is > secter number then progrm should show a erro
#
# 3.if the gusseed number is > secter number then progrm should show a erro as well

# %%
print("Welcome to Number Guessing Game")
print(" ")
print("Gusse the number between 1 to 100")
print(" ")

num = 67

for i in range(1,8):
    user_input = int(input("Enter the Number : "))

    if  user_input <= 0 or user_input >=100:
        print("Invalid Number 💀💀❌❌❌")
    elif user_input > num :
            print ("you'r number is higer")
    elif user_input < num :
            print ("you'r number is lesreer")
    else :
       print("congratulations You'r guess is right")
       print(f"You have gussed the number in {i} attames") 
       break
# Out:
# Welcome to Number Guessing Game
#
# Gusse the number between 1 to 100
# Enter the Number :  67
# congratulations You'r guess is right
# You have gussed the number in 1 attames

# %% [markdown]
# ## Number Guessing Game Level 4

# %%
print("Welcome to Number Guessing Game")
print(" ")
print("Gusse the number between 1 to 100")
print(" ")
print ("You have 7 chanches to guess the number ")
print("")
num = 67

for i in range(1,8):
    user_input = int(input(f"Enter the Number {i} : "))

    if  user_input < 0 or user_input >100:
        print("Invalid Number 💀💀❌❌❌")
    elif user_input > num :
            print ("you'r number is higer")
    elif user_input < num :
            print ("you'r number is lesreer")
    else :
       print("congratulations You'r guess is right") 
       break

if num == user_input :
    print(f"You have gussed the number in {i} attames")
else :
    print("Your lost , try agine")
# Out:
# Welcome to Number Guessing Game
#
# Gusse the number between 1 to 100
#
# You have 7 chanches to guess the number
# Enter the Number 1 :  45
# you'r number is lesreer
# Enter the Number 2 :  56
# you'r number is lesreer
# Enter the Number 3 :  67
# congratulations You'r guess is right
# You have gussed the number in 3 attames

# %% [markdown]
# ## Number Guessing Game Level 5

# %%
import random

# %%
random.randint(1,100)
# Out:
# 77

# %%
import random
print("Welcome to Number Guessing Game")
print(" ")
print("Gusse the number between 1 to 100")
print(" ")
print ("You have 7 chanches to guess the number ")
print("")
num = random.randint(1,100)

for i in range(1,8):
    user_input = int(input(f"Enter the Number {i} : "))

    if  user_input < 0 or user_input > 100:
        print("Invalid Number 💀💀❌❌❌")
    elif user_input > num :
            print ("you'r number is higher")
    elif user_input < num :
            print ("you'r number is lesser")
    else :
       print("congratulations You'r guess is right") 
       break

if num == user_input :
    print(f"You have gussed the number in {i} attames")
else :
    print("Your lost , try agine")
# Out:
# Welcome to Number Guessing Game
#
# Gusse the number between 1 to 100
#
# You have 7 chanches to guess the number
# Enter the Number 1 :  20
# you'r number is higher
# Enter the Number 2 :  10
# you'r number is lesser
# Enter the Number 3 :  15
# you'r number is higher
# Enter the Number 4 :  14
# you'r number is higher
# Enter the Number 5 :  13
# you'r number is higher
# Enter the Number 6 :  12
# congratulations You'r guess is right
# You have gussed the number in 6 attames

# %% [markdown]
# #### taking off the limts of the try

# %%
import random

print("Welcome to Number Guessing Game")
print(" ")
print("Guess the number between 1 to 100")
print("")

num = random.randint(1, 100)
guesses = 0   # count guesses

while True:
        user_input = int(input("Enter the Number : "))
        guesses += 1   # increase count
    
        if user_input < 1 or user_input > 100:
            print("Invalid Number 💀💀❌❌❌")
        elif user_input > num:
            print("Your number is higher")
        elif user_input < num:
            print("Your number is lesser")
        else:
            print("🎉 Congratulations! Your guess is right")
            print("You guessed the number in", guesses, "attempts")
            break
# Out:
# Welcome to Number Guessing Game
#
# Guess the number between 1 to 100
# Enter the Number :  41
# Your number is lesser
# Enter the Number :  50
# Your number is lesser
# Enter the Number :  60
# Your number is lesser
# Enter the Number :  80
# Your number is higher
# Enter the Number :  70
# 🎉 Congratulations! Your guess is right
# You guessed the number in 5 attempts

# %% [markdown]
# ## Number Guessing Game Level 6

# %% [markdown]
# #### Handleing invalid valuse

# %%
import random

print("Welcome to Number Guessing Game")
print(" ")
print("Guess the number between 1 to 100")
print("")

num = random.randint(1, 100)
guesses = 0   # count guesses

while True:

    try:
        user_input = int(input("Enter the Number : "))
        guesses += 1   # increase count
    
        if user_input < 1 or user_input > 100:
            print("Invalid Number 💀💀❌❌❌")
        elif user_input > num:
            print("Your number is higher")
        elif user_input < num:
            print("Your number is lesser")
        else:
            print("🎉 Congratulations! Your guess is right")
            print("You guessed the number in", guesses, "attempts")
            break
    except ValueError:
        print ("Invalid value 🙏🥀")
# Out:
# Welcome to Number Guessing Game
#
# Guess the number between 1 to 100
# Enter the Number :  50
# Your number is lesser
# Enter the Number :  80
# Your number is higher
# Enter the Number :  60
# Your number is lesser
# Enter the Number :  70
# Your number is higher
# Enter the Number :  65
# 🎉 Congratulations! Your guess is right
# You guessed the number in 5 attempts

# %% [markdown]
# ## Number Guessing Game Level 7

# %%
def num_guessing_game ():
    import random
    
    print("Welcome to Number Guessing Game")
    print(" ")
    print("Guess the number between 1 to 100")
    print("")
    
    num = random.randint(1, 100)
    guesses = 0   # count guesses
    
    while True:
    
        try:
            user_input = int(input("Enter the Number : "))
            guesses += 1   # increase count
        
            if user_input < 1 or user_input > 100:
                print("Invalid Number 💀💀❌❌❌")
            elif user_input > num:
                print("Your number is higher")
            elif user_input < num:
                print("Your number is lesser")
            else:
                print("🎉 Congratulations! Your guess is right")
                print("You guessed the number in", guesses, "attempts")
                break
        except ValueError:
            print ("Invalid value 🙏🥀")

# %%
num_guessing_game ()
# Out:
# Welcome to Number Guessing Game
#
# Guess the number between 1 to 100
# Enter the Number :  50
# Your number is lesser
# Enter the Number :  80
# Your number is lesser
# Enter the Number :  90
# Your number is lesser
# Enter the Number :  95
# Your number is higher
# Enter the Number :  93
# Your number is lesser
# Enter the Number :  34
# Your number is lesser
# Enter the Number :  94
# 🎉 Congratulations! Your guess is right
# You guessed the number in 7 attempts

# %%
print("Thank you for playing the Number Guessing Game! Goodbye!")
# Out:
# Thank you for playing the Number Guessing Game! Goodbye!
